# %%
import pandas as pd
from best_fit_svmgridsearch import model
from sklearn.metrics import mean_absolute_error
from sklearn.preprocessing import StandardScaler

# %%
#Reading file without labels.
data=pd.read_csv('Project_dataset_unlabelled.csv')
#Labels of this file will be predicted by the prepared model.
data.head()
# Out:
#      LV    M  Speed  Visual  Audio  Survey_Score
# 0  1.00  1.0      1     1.0    1.0           1.00
# 1  1.00  1.0      1     1.0    1.0           0.95
# 2  1.00  1.0      1     1.0    1.0           0.90
# 3  1.00  1.0      1     1.0    1.0           0.85
# 4  0.85  1.0      1     1.0    1.0           1.00

# %%
#Reading file with labels.
dataset = pd.read_csv('Project_dataset.csv')
#Predictions made for the above file will be compared with labels present in this file.
y_given = dataset.Label #The type of y_given is Pandas Series.
dataset.head()
# Out:
#      LV    M  Speed  Visual  Audio  Survey_Score   Label
# 0  1.00  1.0      1     1.0    1.0           1.00      3
# 1  1.00  1.0      1     1.0    1.0           0.95      3
# 2  1.00  1.0      1     1.0    1.0           0.90      3
# 3  1.00  1.0      1     1.0    1.0           0.85      3
# 4  0.85  1.0      1     1.0    1.0           1.00      3

# %%
#StandardScalar is used for preprocessing of data.
#'copy' is False, which means copies are avoid and inplace scaling is done instead.
sc=StandardScaler(copy=False)
sc.fit_transform(data)
# Out:
# array([[ 1.67691473,  1.11461532,  1.        ,  1.49485387,  0.81775953,
#          1.65144565],
#        [ 1.67691473,  1.11461532,  1.        ,  1.49485387,  0.81775953,
#          1.48630108],
#        [ 1.67691473,  1.11461532,  1.        ,  1.49485387,  0.81775953,
#          1.32115652],
#        ...,
#        [-2.65969096, -1.87061527, -1.        , -2.10213826, -2.68043402,
#         -1.32115652],
#        [-2.65969096, -1.87061527, -1.        , -2.10213826, -2.68043402,
#         -1.48630108],
#        [-2.65969096, -1.87061527, -1.        , -2.10213826, -2.68043402,
#         -1.65144565]])

# %%
#Making predictions using SVM model with GridSearch.
y_pred = model.predict(data)
#Return type of predict is numpy array.
#Type casting prediction into Pandas Series.
y_pred = pd.Series(y_pred)
y_pred.head()
# Out:
# 0    3
# 1    3
# 2    3
# 3    3
# 4    3
# dtype: int64

# %%
#Calculating the error between predicted values and the given values
model_error = mean_absolute_error(y_pred, y_given)
model_error
# Out:
# 0.0030921459492888066

# %%
print("On testing the model, we find that the model gives results with an error rate of %.2f" % (100 * model_error)
      , '%.', sep = '')
# Out:
# On testing the model, we find that the model gives results with an error rate of 0.31%.
